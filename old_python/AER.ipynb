# %%
import pandas as pd

# %%
chunk_iter = pd.read_sas("alltic_viobydy_q_052825_142505.sas7bdat",chunksize=10000, encoding = "utf-8")
alltic = next(chunk_iter)

# %%
for col in alltic.columns:
    print(col)
# Out:
# DATE
# adjusted
# volume
# DGS10
# DGS2
# DGS3
# DGS1
# DGS3mo
# DGS6mo
# dgs2p5
# dgs1p5
# dgs15mo
# dgs9mo
# CPI
# ppi
# unemprate
# laborpart
# indprod
# ffr
# ycurve10y3m
# ycurve10y2y
# moodycorpbondyield
# snp500rets
# snp500
# rollmean
# rollmean1yr
# rollstd
# rollstd1yr
# rollstd3mo
# rollstd6mo
# rollstd9mo
# rollstd15mo
# rollstd18mo
# rollstd24mo
# ticker
# returns
# mean_bb_price3mos1
# mean_bb_price6mos1
# mean_bb_price9mos1
# mean_bb_price12mos1
# mean_bb_price15mos1
# mean_bb_price18mos1
# mean_bb_price24mos1
# mean_bb_price3mos2
# mean_bb_price6mos2
# mean_bb_price9mos2
# mean_bb_price12mos2
# mean_bb_price15mos2
# mean_bb_price18mos2
# mean_bb_price24mos2
# mean_bb_price3mos3
# mean_bb_price6mos3
# mean_bb_price9mos3
# mean_bb_price12mos3
# mean_bb_price15mos3
# mean_bb_price18mos3
# mean_bb_price24mos3
# mean_bb_price3mos4
# mean_bb_price6mos4
# mean_bb_price9mos4
# mean_bb_price12mos4
# mean_bb_price15mos4
# mean_bb_price18mos4
# mean_bb_price24mos4
# mean_bbb_price24mos
# mean_bbb_price30mos
# mean_bbb_price36mos
# pct_above3mos1
# pct_above6mos1
# pct_above9mos1
# pct_above12mos1
# pct_above15mos1
# pct_above18mos1
# pct_above24mos1
# pct_above3mos2
# pct_above6mos2
# pct_above9mos2
# pct_above12mos2
# pct_above15mos2
# pct_above18mos2
# pct_above24mos2
# pct_above3mos3
# pct_above6mos3
# pct_above9mos3
# pct_above12mos3
# pct_above15mos3
# pct_above18mos3
# pct_above24mos3
# pct_above3mos4
# pct_above6mos4
# pct_above9mos4
# pct_above12mos4
# pct_above15mos4
# pct_above18mos4
# pct_above24mos4
# pct_bbbabove24mos
# pct_bbbabove30mos
# pct_bbbabove36mos
# pct_below3mos1
# pct_below6mos1
# pct_below9mos1
# pct_below12mos1
# pct_below15mos1
# pct_below18mos1
# pct_below24mos1
# pct_below3mos2
# pct_below6mos2
# pct_below9mos2
# pct_below12mos2
# pct_below15mos2
# pct_below18mos2
# pct_below24mos2
# pct_below3mos3
# pct_below6mos3
# pct_below9mos3
# pct_below12mos3
# pct_below15mos3
# pct_below18mos3
# pct_below24mos3
# pct_below3mos4
# pct_below6mos4
# pct_below9mos4
# pct_below12mos4
# pct_below15mos4
# pct_below18mos4
# pct_below24mos4
# pct_bbbelow24mos
# pct_bbbelow30mos
# pct_bbbelow36mos
# wgt3mos
# wgt6mos
# wgt9mos
# wgt12mos
# wgt15mos
# wgt18mos
# wgt24mos
# wgtbbb24mos
# wgtbbb30mos
# wgtbbb36mos
# std3mosfwd
# std6mosfwd
# std9mosfwd
# std12mosfwd
# std15mosfwd
# std18mosfwd
# std24mosfwd
# stdbbb24mosfwd
# stdbbb30mosfwd
# stdbbb36mosfwd
# market_cap
# sector
# mktcap_pctl
# adtv5day
# adtv21day
# fin_price
# notional
# shares
# aep3mos1
# aep6mos1
# aep9mos1
# aep12mos1
# aep15mos1
# aep18mos1
# aep24mos1
# aep6mmos1
# aep9mmos1
# aep12mmos1
# aep15mmos1
# aep18mmos1
# aep24mmos1
# aer3mos1
# aer6mos1
# aer9mos1
# aer12mos1
# aer15mos1
# aer18mos1
# aer24mos1
# aer6mmos1
# aer9mmos1
# aer12mmos1
# aer15mmos1
# aer18mmos1
# aer24mmos1
# aep3mos2
# aep6mos2
# aep9mos2
# aep12mos2
# aep15mos2
# aep18mos2
# aep24mos2
# aep6mmos2
# aep9mmos2
# aep12mmos2
# aep15mmos2
# aep18mmos2
# aep24mmos2
# aer3mos2
# aer6mos2
# aer9mos2
# aer12mos2
# aer15mos2
# aer18mos2
# aer24mos2
# aer6mmos2
# aer9mmos2
# aer12mmos2
# aer15mmos2
# aer18mmos2
# aer24mmos2
# aep3mos3
# aep6mos3
# aep9mos3
# aep12mos3
# aep15mos3
# aep18mos3
# aep24mos3
# aep6mmos3
# aep9mmos3
# aep12mmos3
# aep15mmos3
# aep18mmos3
# aep24mmos3
# aer3mos3
# aer6mos3
# aer9mos3
# aer12mos3
# aer15mos3
# aer18mos3
# aer24mos3
# aer6mmos3
# aer9mmos3
# aer12mmos3
# aer15mmos3
# aer18mmos3
# aer24mmos3
# aep3mos4
# aep6mos4
# aep9mos4
# aep12mos4
# aep15mos4
# aep18mos4
# aep24mos4
# aep6mmos4
# aep9mmos4
# aep12mmos4
# aep15mmos4
# aep18mmos4
# aep24mmos4
# aer3mos4
# aer6mos4
# aer9mos4
# aer12mos4
# aer15mos4
# aer18mos4
# aer24mos4
# aer6mmos4
# aer9mmos4
# aer12mmos4
# aer15mmos4
# aer18mmos4
# aer24mmos4
# callp3_1
# callp6_1
# callp9_1
# callp12_1
# callp15_1
# callp18_1
# callp24_1
# putp3_1
# putp6_1
# putp9_1
# putp12_1
# putp15_1
# putp18_1
# putp24_1
# dputp3_1
# dputp6_1
# dputp9_1
# dputp12_1
# dputp15_1
# dputp18_1
# dputp24_1
# coup3_1
# coup6_1
# coup9_1
# coup12_1
# coup15_1
# coup18_1
# coup24_1
# callp3_2
# callp6_2
# callp9_2
# callp12_2
# callp15_2
# callp18_2
# callp24_2
# putp3_2
# putp6_2
# putp9_2
# putp12_2
# putp15_2
# putp18_2
# putp24_2
# dputp3_2
# dputp6_2
# dputp9_2
# dputp12_2
# dputp15_2
# dputp18_2
# dputp24_2
# coup3_2
# coup6_2
# coup9_2
# coup12_2
# coup15_2
# coup18_2
# coup24_2
# callp3_3
# callp6_3
# callp9_3
# callp12_3
# callp15_3
# callp18_3
# callp24_3
# putp3_3
# putp6_3
# putp9_3
# putp12_3
# putp15_3
# putp18_3
# putp24_3
# dputp3_3
# dputp6_3
# dputp9_3
# dputp12_3
# dputp15_3
# dputp18_3
# dputp24_3
# coup3_3
# coup6_3
# coup9_3
# coup12_3
# coup15_3
# coup18_3
# coup24_3
# callp3_4
# callp6_4
# callp9_4
# callp12_4
# callp15_4
# callp18_4
# callp24_4
# putp3_4
# putp6_4
# putp9_4
# putp12_4
# putp15_4
# putp18_4
# putp24_4
# dputp3_4
# dputp6_4
# dputp9_4
# dputp12_4
# dputp15_4
# dputp18_4
# dputp24_4
# coup3_4
# coup6_4
# coup9_4
# coup12_4
# coup15_4
# coup18_4
# coup24_4
# aep_buf24mos
# aep_buf30mos
# aep_buf36mos
# aer_buf24mos
# aer_buf30mos
# aer_buf36mos
# coupbuf24
# coupbuf30
# coupbuf36
# strike_buf
# digputpay_buf
# dputp_buf24
# dputp_buf30
# dputp_buf36
# aerx3mos1
# aerx6mos1
# aerx9mos1
# aerx12mos1
# aerx15mos1
# aerx18mos1
# aerx24mos1
# aerx6mmos1
# aerx9mmos1
# aerx12mmos1
# aerx15mmos1
# aerx18mmos1
# aerx24mmos1
# aerx3mos2
# aerx6mos2
# aerx9mos2
# aerx12mos2
# aerx15mos2
# aerx18mos2
# aerx24mos2
# aerx6mmos2
# aerx9mmos2
# aerx12mmos2
# aerx15mmos2
# aerx18mmos2
# aerx24mmos2
# aerx3mos3
# aerx6mos3
# aerx9mos3
# aerx12mos3
# aerx15mos3
# aerx18mos3
# aerx24mos3
# aerx6mmos3
# aerx9mmos3
# aerx12mmos3
# aerx15mmos3
# aerx18mmos3
# aerx24mmos3
# aerx3mos4
# aerx6mos4
# aerx9mos4
# aerx12mos4
# aerx15mos4
# aerx18mos4
# aerx24mos4
# aerx6mmos4
# aerx9mmos4
# aerx12mmos4
# aerx15mmos4
# aerx18mmos4
# aerx24mmos4
# aerx_bbb24mos
# aerx_bbb30mos
# aerx_bbb36mos
# xstd3mosfwd
# xstd6mosfwd
# xstd9mosfwd
# xstd12mosfwd
# xstd15mosfwd
# xstd18mosfwd
# xstd24mosfwd
# pct_xabove3mos1
# pct_xabove6mos1
# pct_xabove9mos1
# pct_xabove12mos1
# pct_xabove15mos1
# pct_xabove18mos1
# pct_xabove24mos1
# pct_xbelow3mos1
# pct_xbelow6mos1
# pct_xbelow9mos1
# pct_xbelow12mos1
# pct_xbelow15mos1
# pct_xbelow18mos1
# pct_xbelow24mos1
# mean_xbb_price3mos1
# mean_xbb_price6mos1
# mean_xbb_price9mos1
# mean_xbb_price12mos1
# mean_xbb_price15mos1
# mean_xbb_price18mos1
# mean_xbb_price24mos1
# pct_xabove3mos2
# pct_xabove6mos2
# pct_xabove9mos2
# pct_xabove12mos2
# pct_xabove15mos2
# pct_xabove18mos2
# pct_xabove24mos2
# pct_xbelow3mos2
# pct_xbelow6mos2
# pct_xbelow9mos2
# pct_xbelow12mos2
# pct_xbelow15mos2
# pct_xbelow18mos2
# pct_xbelow24mos2
# mean_xbb_price3mos2
# mean_xbb_price6mos2
# mean_xbb_price9mos2
# mean_xbb_price12mos2
# mean_xbb_price15mos2
# mean_xbb_price18mos2
# mean_xbb_price24mos2
# pct_xabove3mos3
# pct_xabove6mos3
# pct_xabove9mos3
# pct_xabove12mos3
# pct_xabove15mos3
# pct_xabove18mos3
# pct_xabove24mos3
# pct_xbelow3mos3
# pct_xbelow6mos3
# pct_xbelow9mos3
# pct_xbelow12mos3
# pct_xbelow15mos3
# pct_xbelow18mos3
# pct_xbelow24mos3
# mean_xbb_price3mos3
# mean_xbb_price6mos3
# mean_xbb_price9mos3
# mean_xbb_price12mos3
# mean_xbb_price15mos3
# mean_xbb_price18mos3
# mean_xbb_price24mos3
# pct_xabove3mos4
# pct_xabove6mos4
# pct_xabove9mos4
# pct_xabove12mos4
# pct_xabove15mos4
# pct_xabove18mos4
# pct_xabove24mos4
# pct_xbelow3mos4
# pct_xbelow6mos4
# pct_xbelow9mos4
# pct_xbelow12mos4
# pct_xbelow15mos4
# pct_xbelow18mos4
# pct_xbelow24mos4
# mean_xbb_price3mos4
# mean_xbb_price6mos4
# mean_xbb_price9mos4
# mean_xbb_price12mos4
# mean_xbb_price15mos4
# mean_xbb_price18mos4
# mean_xbb_price24mos4
# xstdbbb24mosfwd
# xstdbbb30mosfwd
# xstdbbb36mosfwd
# pct_xbbbabove24mos
# pct_xbbbabove30mos
# pct_xbbbabove36mos
# pct_xbbbelow24mos
# pct_xbbbelow30mos
# pct_xbbbelow36mos
# mean_xbbb_price24mos
# mean_xbbb_price30mos
# mean_xbbb_price36mos
# aer24pctl_1_1
# aer24pctl_1_2
# aer24pctl_1_3
# aer24pctl_1_4
# aer24pctl_1_5
# aer24pctl_1_6
# aer24pctl_1_7
# aer24pctl_1_8
# aer24pctl_1_9
# aer24pctl_1_10
# aer24pctl_1_11
# aer24mean1
# aer24std1
# aer24_radj_mean1
# aer24iqr1
# aer24_radj_med1
# aer24pctl_2_1
# aer24pctl_2_2
# aer24pctl_2_3
# aer24pctl_2_4
# aer24pctl_2_5
# aer24pctl_2_6
# aer24pctl_2_7
# aer24pctl_2_8
# aer24pctl_2_9
# aer24pctl_2_10
# aer24pctl_2_11
# aer24mean2
# aer24std2
# aer24_radj_mean2
# aer24iqr2
# aer24_radj_med2
# aer24pctl_3_1
# aer24pctl_3_2
# aer24pctl_3_3
# aer24pctl_3_4
# aer24pctl_3_5
# aer24pctl_3_6
# aer24pctl_3_7
# aer24pctl_3_8
# aer24pctl_3_9
# aer24pctl_3_10
# aer24pctl_3_11
# aer24mean3
# aer24std3
# aer24_radj_mean3
# aer24iqr3
# aer24_radj_med3
# aer24pctl_4_1
# aer24pctl_4_2
# aer24pctl_4_3
# aer24pctl_4_4
# aer24pctl_4_5
# aer24pctl_4_6
# aer24pctl_4_7
# aer24pctl_4_8
# aer24pctl_4_9
# aer24pctl_4_10
# aer24pctl_4_11
# aer24mean4
# aer24std4
# aer24_radj_mean4
# aer24iqr4
# aer24_radj_med4
# aer24mpctl_1_1
# aer24mpctl_1_2
# aer24mpctl_1_3
# aer24mpctl_1_4
# aer24mpctl_1_5
# aer24mpctl_1_6
# aer24mpctl_1_7
# aer24mpctl_1_8
# aer24mpctl_1_9
# aer24mpctl_1_10
# aer24mpctl_1_11
# aer24mmean1
# aer24mstd1
# aer24m_radj_mean1
# aer24miqr1
# aer24m_radj_med1
# aer24mpctl_2_1
# aer24mpctl_2_2
# aer24mpctl_2_3
# aer24mpctl_2_4
# aer24mpctl_2_5
# aer24mpctl_2_6
# aer24mpctl_2_7
# aer24mpctl_2_8
# aer24mpctl_2_9
# aer24mpctl_2_10
# aer24mpctl_2_11
# aer24mmean2
# aer24mstd2
# aer24m_radj_mean2
# aer24miqr2
# aer24m_radj_med2
# aer24mpctl_3_1
# aer24mpctl_3_2
# aer24mpctl_3_3
# aer24mpctl_3_4
# aer24mpctl_3_5
# aer24mpctl_3_6
# aer24mpctl_3_7
# aer24mpctl_3_8
# aer24mpctl_3_9
# aer24mpctl_3_10
# aer24mpctl_3_11
# aer24mmean3
# aer24mstd3
# aer24m_radj_mean3
# aer24miqr3
# aer24m_radj_med3
# aer24mpctl_4_1
# aer24mpctl_4_2
# aer24mpctl_4_3
# aer24mpctl_4_4
# aer24mpctl_4_5
# aer24mpctl_4_6
# aer24mpctl_4_7
# aer24mpctl_4_8
# aer24mpctl_4_9
# aer24mpctl_4_10
# aer24mpctl_4_11
# aer24mmean4
# aer24mstd4
# aer24m_radj_mean4
# aer24miqr4
# aer24m_radj_med4
# aer18pctl_1_1
# aer18pctl_1_2
# aer18pctl_1_3
# aer18pctl_1_4
# aer18pctl_1_5
# aer18pctl_1_6
# aer18pctl_1_7
# aer18pctl_1_8
# aer18pctl_1_9
# aer18pctl_1_10
# aer18pctl_1_11
# aer18mean1
# aer18std1
# aer18_radj_mean1
# aer18iqr1
# aer18_radj_med1
# aer18pctl_2_1
# aer18pctl_2_2
# aer18pctl_2_3
# aer18pctl_2_4
# aer18pctl_2_5
# aer18pctl_2_6
# aer18pctl_2_7
# aer18pctl_2_8
# aer18pctl_2_9
# aer18pctl_2_10
# aer18pctl_2_11
# aer18mean2
# aer18std2
# aer18_radj_mean2
# aer18iqr2
# aer18_radj_med2
# aer18pctl_3_1
# aer18pctl_3_2
# aer18pctl_3_3
# aer18pctl_3_4
# aer18pctl_3_5
# aer18pctl_3_6
# aer18pctl_3_7
# aer18pctl_3_8
# aer18pctl_3_9
# aer18pctl_3_10
# aer18pctl_3_11
# aer18mean3
# aer18std3
# aer18_radj_mean3
# aer18iqr3
# aer18_radj_med3
# aer18pctl_4_1
# aer18pctl_4_2
# aer18pctl_4_3
# aer18pctl_4_4
# aer18pctl_4_5
# aer18pctl_4_6
# aer18pctl_4_7
# aer18pctl_4_8
# aer18pctl_4_9
# aer18pctl_4_10
# aer18pctl_4_11
# aer18mean4
# aer18std4
# aer18_radj_mean4
# aer18iqr4
# aer18_radj_med4
# aer18mpctl_1_1
# aer18mpctl_1_2
# aer18mpctl_1_3
# aer18mpctl_1_4
# aer18mpctl_1_5
# aer18mpctl_1_6
# aer18mpctl_1_7
# aer18mpctl_1_8
# aer18mpctl_1_9
# aer18mpctl_1_10
# aer18mpctl_1_11
# aer18mmean1
# aer18mstd1
# aer18m_radj_mean1
# aer18miqr1
# aer18m_radj_med1
# aer18mpctl_2_1
# aer18mpctl_2_2
# aer18mpctl_2_3
# aer18mpctl_2_4
# aer18mpctl_2_5
# aer18mpctl_2_6
# aer18mpctl_2_7
# aer18mpctl_2_8
# aer18mpctl_2_9
# aer18mpctl_2_10
# aer18mpctl_2_11
# aer18mmean2
# aer18mstd2
# aer18m_radj_mean2
# aer18miqr2
# aer18m_radj_med2
# aer18mpctl_3_1
# aer18mpctl_3_2
# aer18mpctl_3_3
# aer18mpctl_3_4
# aer18mpctl_3_5
# aer18mpctl_3_6
# aer18mpctl_3_7
# aer18mpctl_3_8
# aer18mpctl_3_9
# aer18mpctl_3_10
# aer18mpctl_3_11
# aer18mmean3
# aer18mstd3
# aer18m_radj_mean3
# aer18miqr3
# aer18m_radj_med3
# aer18mpctl_4_1
# aer18mpctl_4_2
# aer18mpctl_4_3
# aer18mpctl_4_4
# aer18mpctl_4_5
# aer18mpctl_4_6
# aer18mpctl_4_7
# aer18mpctl_4_8
# aer18mpctl_4_9
# aer18mpctl_4_10
# aer18mpctl_4_11
# aer18mmean4
# aer18mstd4
# aer18m_radj_mean4
# aer18miqr4
# aer18m_radj_med4
# aer15pctl_1_1
# aer15pctl_1_2
# aer15pctl_1_3
# aer15pctl_1_4
# aer15pctl_1_5
# aer15pctl_1_6
# aer15pctl_1_7
# aer15pctl_1_8
# aer15pctl_1_9
# aer15pctl_1_10
# aer15pctl_1_11
# aer15mean1
# aer15std1
# aer15_radj_mean1
# aer15iqr1
# aer15_radj_med1
# aer15pctl_2_1
# aer15pctl_2_2
# aer15pctl_2_3
# aer15pctl_2_4
# aer15pctl_2_5
# aer15pctl_2_6
# aer15pctl_2_7
# aer15pctl_2_8
# aer15pctl_2_9
# aer15pctl_2_10
# aer15pctl_2_11
# aer15mean2
# aer15std2
# aer15_radj_mean2
# aer15iqr2
# aer15_radj_med2
# aer15pctl_3_1
# aer15pctl_3_2
# aer15pctl_3_3
# aer15pctl_3_4
# aer15pctl_3_5
# aer15pctl_3_6
# aer15pctl_3_7
# aer15pctl_3_8
# aer15pctl_3_9
# aer15pctl_3_10
# aer15pctl_3_11
# aer15mean3
# aer15std3
# aer15_radj_mean3
# aer15iqr3
# aer15_radj_med3
# aer15pctl_4_1
# aer15pctl_4_2
# aer15pctl_4_3
# aer15pctl_4_4
# aer15pctl_4_5
# aer15pctl_4_6
# aer15pctl_4_7
# aer15pctl_4_8
# aer15pctl_4_9
# aer15pctl_4_10
# aer15pctl_4_11
# aer15mean4
# aer15std4
# aer15_radj_mean4
# aer15iqr4
# aer15_radj_med4
# aer15mpctl_1_1
# aer15mpctl_1_2
# aer15mpctl_1_3
# aer15mpctl_1_4
# aer15mpctl_1_5
# aer15mpctl_1_6
# aer15mpctl_1_7
# aer15mpctl_1_8
# aer15mpctl_1_9
# aer15mpctl_1_10
# aer15mpctl_1_11
# aer15mmean1
# aer15mstd1
# aer15m_radj_mean1
# aer15miqr1
# aer15m_radj_med1
# aer15mpctl_2_1
# aer15mpctl_2_2
# aer15mpctl_2_3
# aer15mpctl_2_4
# aer15mpctl_2_5
# aer15mpctl_2_6
# aer15mpctl_2_7
# aer15mpctl_2_8
# aer15mpctl_2_9
# aer15mpctl_2_10
# aer15mpctl_2_11
# aer15mmean2
# aer15mstd2
# aer15m_radj_mean2
# aer15miqr2
# aer15m_radj_med2
# aer15mpctl_3_1
# aer15mpctl_3_2
# aer15mpctl_3_3
# aer15mpctl_3_4
# aer15mpctl_3_5
# aer15mpctl_3_6
# aer15mpctl_3_7
# aer15mpctl_3_8
# aer15mpctl_3_9
# aer15mpctl_3_10
# aer15mpctl_3_11
# aer15mmean3
# aer15mstd3
# aer15m_radj_mean3
# aer15miqr3
# aer15m_radj_med3
# aer15mpctl_4_1
# aer15mpctl_4_2
# aer15mpctl_4_3
# aer15mpctl_4_4
# aer15mpctl_4_5
# aer15mpctl_4_6
# aer15mpctl_4_7
# aer15mpctl_4_8
# aer15mpctl_4_9
# aer15mpctl_4_10
# aer15mpctl_4_11
# aer15mmean4
# aer15mstd4
# aer15m_radj_mean4
# aer15miqr4
# aer15m_radj_med4
# aer12pctl_1_1
# aer12pctl_1_2
# aer12pctl_1_3
# aer12pctl_1_4
# aer12pctl_1_5
# aer12pctl_1_6
# aer12pctl_1_7
# aer12pctl_1_8
# aer12pctl_1_9
# aer12pctl_1_10
# aer12pctl_1_11
# aer12mean1
# aer12std1
# aer12_radj_mean1
# aer12iqr1
# aer12_radj_med1
# aer12pctl_2_1
# aer12pctl_2_2
# aer12pctl_2_3
# aer12pctl_2_4
# aer12pctl_2_5
# aer12pctl_2_6
# aer12pctl_2_7
# aer12pctl_2_8
# aer12pctl_2_9
# aer12pctl_2_10
# aer12pctl_2_11
# aer12mean2
# aer12std2
# aer12_radj_mean2
# aer12iqr2
# aer12_radj_med2
# aer12pctl_3_1
# aer12pctl_3_2
# aer12pctl_3_3
# aer12pctl_3_4
# aer12pctl_3_5
# aer12pctl_3_6
# aer12pctl_3_7
# aer12pctl_3_8
# aer12pctl_3_9
# aer12pctl_3_10
# aer12pctl_3_11
# aer12mean3
# aer12std3
# aer12_radj_mean3
# aer12iqr3
# aer12_radj_med3
# aer12pctl_4_1
# aer12pctl_4_2
# aer12pctl_4_3
# aer12pctl_4_4
# aer12pctl_4_5
# aer12pctl_4_6
# aer12pctl_4_7
# aer12pctl_4_8
# aer12pctl_4_9
# aer12pctl_4_10
# aer12pctl_4_11
# aer12mean4
# aer12std4
# aer12_radj_mean4
# aer12iqr4
# aer12_radj_med4
# aer12mpctl_1_1
# aer12mpctl_1_2
# aer12mpctl_1_3
# aer12mpctl_1_4
# aer12mpctl_1_5
# aer12mpctl_1_6
# aer12mpctl_1_7
# aer12mpctl_1_8
# aer12mpctl_1_9
# aer12mpctl_1_10
# aer12mpctl_1_11
# aer12mmean1
# aer12mstd1
# aer12m_radj_mean1
# aer12miqr1
# aer12m_radj_med1
# aer12mpctl_2_1
# aer12mpctl_2_2
# aer12mpctl_2_3
# aer12mpctl_2_4
# aer12mpctl_2_5
# aer12mpctl_2_6
# aer12mpctl_2_7
# aer12mpctl_2_8
# aer12mpctl_2_9
# aer12mpctl_2_10
# aer12mpctl_2_11
# aer12mmean2
# aer12mstd2
# aer12m_radj_mean2
# aer12miqr2
# aer12m_radj_med2
# aer12mpctl_3_1
# aer12mpctl_3_2
# aer12mpctl_3_3
# aer12mpctl_3_4
# aer12mpctl_3_5
# aer12mpctl_3_6
# aer12mpctl_3_7
# aer12mpctl_3_8
# aer12mpctl_3_9
# aer12mpctl_3_10
# aer12mpctl_3_11
# aer12mmean3
# aer12mstd3
# aer12m_radj_mean3
# aer12miqr3
# aer12m_radj_med3
# aer12mpctl_4_1
# aer12mpctl_4_2
# aer12mpctl_4_3
# aer12mpctl_4_4
# aer12mpctl_4_5
# aer12mpctl_4_6
# aer12mpctl_4_7
# aer12mpctl_4_8
# aer12mpctl_4_9
# aer12mpctl_4_10
# aer12mpctl_4_11
# aer12mmean4
# aer12mstd4
# aer12m_radj_mean4
# aer12miqr4
# aer12m_radj_med4
# aer9pctl_1_1
# aer9pctl_1_2
# aer9pctl_1_3
# aer9pctl_1_4
# aer9pctl_1_5
# aer9pctl_1_6
# aer9pctl_1_7
# aer9pctl_1_8
# aer9pctl_1_9
# aer9pctl_1_10
# aer9pctl_1_11
# aer9mean1
# aer9std1
# aer9_radj_mean1
# aer9iqr1
# aer9_radj_med1
# aer9pctl_2_1
# aer9pctl_2_2
# aer9pctl_2_3
# aer9pctl_2_4
# aer9pctl_2_5
# aer9pctl_2_6
# aer9pctl_2_7
# aer9pctl_2_8
# aer9pctl_2_9
# aer9pctl_2_10
# aer9pctl_2_11
# aer9mean2
# aer9std2
# aer9_radj_mean2
# aer9iqr2
# aer9_radj_med2
# aer9pctl_3_1
# aer9pctl_3_2
# aer9pctl_3_3
# aer9pctl_3_4
# aer9pctl_3_5
# aer9pctl_3_6
# aer9pctl_3_7
# aer9pctl_3_8
# aer9pctl_3_9
# aer9pctl_3_10
# aer9pctl_3_11
# aer9mean3
# aer9std3
# aer9_radj_mean3
# aer9iqr3
# aer9_radj_med3
# aer9pctl_4_1
# aer9pctl_4_2
# aer9pctl_4_3
# aer9pctl_4_4
# aer9pctl_4_5
# aer9pctl_4_6
# aer9pctl_4_7
# aer9pctl_4_8
# aer9pctl_4_9
# aer9pctl_4_10
# aer9pctl_4_11
# aer9mean4
# aer9std4
# aer9_radj_mean4
# aer9iqr4
# aer9_radj_med4
# aer9mpctl_1_1
# aer9mpctl_1_2
# aer9mpctl_1_3
# aer9mpctl_1_4
# aer9mpctl_1_5
# aer9mpctl_1_6
# aer9mpctl_1_7
# aer9mpctl_1_8
# aer9mpctl_1_9
# aer9mpctl_1_10
# aer9mpctl_1_11
# aer9mmean1
# aer9mstd1
# aer9m_radj_mean1
# aer9miqr1
# aer9m_radj_med1
# aer9mpctl_2_1
# aer9mpctl_2_2
# aer9mpctl_2_3
# aer9mpctl_2_4
# aer9mpctl_2_5
# aer9mpctl_2_6
# aer9mpctl_2_7
# aer9mpctl_2_8
# aer9mpctl_2_9
# aer9mpctl_2_10
# aer9mpctl_2_11
# aer9mmean2
# aer9mstd2
# aer9m_radj_mean2
# aer9miqr2
# aer9m_radj_med2
# aer9mpctl_3_1
# aer9mpctl_3_2
# aer9mpctl_3_3
# aer9mpctl_3_4
# aer9mpctl_3_5
# aer9mpctl_3_6
# aer9mpctl_3_7
# aer9mpctl_3_8
# aer9mpctl_3_9
# aer9mpctl_3_10
# aer9mpctl_3_11
# aer9mmean3
# aer9mstd3
# aer9m_radj_mean3
# aer9miqr3
# aer9m_radj_med3
# aer9mpctl_4_1
# aer9mpctl_4_2
# aer9mpctl_4_3
# aer9mpctl_4_4
# aer9mpctl_4_5
# aer9mpctl_4_6
# aer9mpctl_4_7
# aer9mpctl_4_8
# aer9mpctl_4_9
# aer9mpctl_4_10
# aer9mpctl_4_11
# aer9mmean4
# aer9mstd4
# aer9m_radj_mean4
# aer9miqr4
# aer9m_radj_med4
# aer6pctl_1_1
# aer6pctl_1_2
# aer6pctl_1_3
# aer6pctl_1_4
# aer6pctl_1_5
# aer6pctl_1_6
# aer6pctl_1_7
# aer6pctl_1_8
# aer6pctl_1_9
# aer6pctl_1_10
# aer6pctl_1_11
# aer6mean1
# aer6std1
# aer6_radj_mean1
# aer6iqr1
# aer6_radj_med1
# aer6pctl_2_1
# aer6pctl_2_2
# aer6pctl_2_3
# aer6pctl_2_4
# aer6pctl_2_5
# aer6pctl_2_6
# aer6pctl_2_7
# aer6pctl_2_8
# aer6pctl_2_9
# aer6pctl_2_10
# aer6pctl_2_11
# aer6mean2
# aer6std2
# aer6_radj_mean2
# aer6iqr2
# aer6_radj_med2
# aer6pctl_3_1
# aer6pctl_3_2
# aer6pctl_3_3
# aer6pctl_3_4
# aer6pctl_3_5
# aer6pctl_3_6
# aer6pctl_3_7
# aer6pctl_3_8
# aer6pctl_3_9
# aer6pctl_3_10
# aer6pctl_3_11
# aer6mean3
# aer6std3
# aer6_radj_mean3
# aer6iqr3
# aer6_radj_med3
# aer6pctl_4_1
# aer6pctl_4_2
# aer6pctl_4_3
# aer6pctl_4_4
# aer6pctl_4_5
# aer6pctl_4_6
# aer6pctl_4_7
# aer6pctl_4_8
# aer6pctl_4_9
# aer6pctl_4_10
# aer6pctl_4_11
# aer6mean4
# aer6std4
# aer6_radj_mean4
# aer6iqr4
# aer6_radj_med4
# aer6mpctl_1_1
# aer6mpctl_1_2
# aer6mpctl_1_3
# aer6mpctl_1_4
# aer6mpctl_1_5
# aer6mpctl_1_6
# aer6mpctl_1_7
# aer6mpctl_1_8
# aer6mpctl_1_9
# aer6mpctl_1_10
# aer6mpctl_1_11
# aer6mmean1
# aer6mstd1
# aer6m_radj_mean1
# aer6miqr1
# aer6m_radj_med1
# aer6mpctl_2_1
# aer6mpctl_2_2
# aer6mpctl_2_3
# aer6mpctl_2_4
# aer6mpctl_2_5
# aer6mpctl_2_6
# aer6mpctl_2_7
# aer6mpctl_2_8
# aer6mpctl_2_9
# aer6mpctl_2_10
# aer6mpctl_2_11
# aer6mmean2
# aer6mstd2
# aer6m_radj_mean2
# aer6miqr2
# aer6m_radj_med2
# aer6mpctl_3_1
# aer6mpctl_3_2
# aer6mpctl_3_3
# aer6mpctl_3_4
# aer6mpctl_3_5
# aer6mpctl_3_6
# aer6mpctl_3_7
# aer6mpctl_3_8
# aer6mpctl_3_9
# aer6mpctl_3_10
# aer6mpctl_3_11
# aer6mmean3
# aer6mstd3
# aer6m_radj_mean3
# aer6miqr3
# aer6m_radj_med3
# aer6mpctl_4_1
# aer6mpctl_4_2
# aer6mpctl_4_3
# aer6mpctl_4_4
# aer6mpctl_4_5
# aer6mpctl_4_6
# aer6mpctl_4_7
# aer6mpctl_4_8
# aer6mpctl_4_9
# aer6mpctl_4_10
# aer6mpctl_4_11
# aer6mmean4
# aer6mstd4
# aer6m_radj_mean4
# aer6miqr4
# aer6m_radj_med4
# aer3pctl_1_1
# aer3pctl_1_2
# aer3pctl_1_3
# aer3pctl_1_4
# aer3pctl_1_5
# aer3pctl_1_6
# aer3pctl_1_7
# aer3pctl_1_8
# aer3pctl_1_9
# aer3pctl_1_10
# aer3pctl_1_11
# aer3mean1
# aer3std1
# aer3_radj_mean1
# aer3iqr1
# aer3_radj_med1
# aer3pctl_2_1
# aer3pctl_2_2
# aer3pctl_2_3
# aer3pctl_2_4
# aer3pctl_2_5
# aer3pctl_2_6
# aer3pctl_2_7
# aer3pctl_2_8
# aer3pctl_2_9
# aer3pctl_2_10
# aer3pctl_2_11
# aer3mean2
# aer3std2
# aer3_radj_mean2
# aer3iqr2
# aer3_radj_med2
# aer3pctl_3_1
# aer3pctl_3_2
# aer3pctl_3_3
# aer3pctl_3_4
# aer3pctl_3_5
# aer3pctl_3_6
# aer3pctl_3_7
# aer3pctl_3_8
# aer3pctl_3_9
# aer3pctl_3_10
# aer3pctl_3_11
# aer3mean3
# aer3std3
# aer3_radj_mean3
# aer3iqr3
# aer3_radj_med3
# aer3pctl_4_1
# aer3pctl_4_2
# aer3pctl_4_3
# aer3pctl_4_4
# aer3pctl_4_5
# aer3pctl_4_6
# aer3pctl_4_7
# aer3pctl_4_8
# aer3pctl_4_9
# aer3pctl_4_10
# aer3pctl_4_11
# aer3mean4
# aer3std4
# aer3_radj_mean4
# aer3iqr4
# aer3_radj_med4
# aerbbb24pctl_1
# aerbbb24pctl_2
# aerbbb24pctl_3
# aerbbb24pctl_4
# aerbbb24pctl_5
# aerbbb24pctl_6
# aerbbb24pctl_7
# aerbbb24pctl_8
# aerbbb24pctl_9
# aerbbb24pctl_10
# aerbbb24pctl_11
# aerbbb24mean
# aerbbb24std
# aerbbb24_radj_mean
# aerbbb24iqr
# aerbbb24_radj_med
# aerbbb30pctl_1
# aerbbb30pctl_2
# aerbbb30pctl_3
# aerbbb30pctl_4
# aerbbb30pctl_5
# aerbbb30pctl_6
# aerbbb30pctl_7
# aerbbb30pctl_8
# aerbbb30pctl_9
# aerbbb30pctl_10
# aerbbb30pctl_11
# aerbbb30mean
# aerbbb30std
# aerbbb30_radj_mean
# aerbbb30iqr
# aerbbb30_radj_med
# aerbbb36pctl_1
# aerbbb36pctl_2
# aerbbb36pctl_3
# aerbbb36pctl_4
# aerbbb36pctl_5
# aerbbb36pctl_6
# aerbbb36pctl_7
# aerbbb36pctl_8
# aerbbb36pctl_9
# aerbbb36pctl_10
# aerbbb36pctl_11
# aerbbb36mean
# aerbbb36std
# aerbbb36_radj_mean
# aerbbb36iqr
# aerbbb36_radj_med
# SR_aerx3mos1
# SRp_aerx3mos1
# SR_aerx3mos2
# SRp_aerx3mos2
# SR_aerx3mos3
# SRp_aerx3mos3
# SR_aerx3mos4
# SRp_aerx3mos4
# SR_aerx6mos1
# SRp_aerx6mos1
# SR_aerx6mos2
# SRp_aerx6mos2
# SR_aerx6mos3
# SRp_aerx6mos3
# SR_aerx6mos4
# SRp_aerx6mos4
# SR_aerx9mos1
# SRp_aerx9mos1
# SR_aerx9mos2
# SRp_aerx9mos2
# SR_aerx9mos3
# SRp_aerx9mos3
# SR_aerx9mos4
# SRp_aerx9mos4
# SR_aerx12mos1
# SRp_aerx12mos1
# SR_aerx12mos2
# SRp_aerx12mos2
# SR_aerx12mos3
# SRp_aerx12mos3
# SR_aerx12mos4
# SRp_aerx12mos4
# SR_aerx15mos1
# SRp_aerx15mos1
# SR_aerx15mos2
# SRp_aerx15mos2
# SR_aerx15mos3
# SRp_aerx15mos3
# SR_aerx15mos4
# SRp_aerx15mos4
# SR_aerx18mos1
# SRp_aerx18mos1
# SR_aerx18mos2
# SRp_aerx18mos2
# SR_aerx18mos3
# SRp_aerx18mos3
# SR_aerx18mos4
# SRp_aerx18mos4
# SR_aerx24mos1
# SRp_aerx24mos1
# SR_aerx24mos2
# SRp_aerx24mos2
# SR_aerx24mos3
# SRp_aerx24mos3
# SR_aerx24mos4
# SRp_aerx24mos4
# SR_aerx6mmos1
# SRp_aerx6mmos1
# SR_aerx6mmos2
# SRp_aerx6mmos2
# SR_aerx6mmos3
# SRp_aerx6mmos3
# SR_aerx6mmos4
# SRp_aerx6mmos4
# SR_aerx9mmos1
# SRp_aerx9mmos1
# SR_aerx9mmos2
# SRp_aerx9mmos2
# SR_aerx9mmos3
# SRp_aerx9mmos3
# SR_aerx9mmos4
# SRp_aerx9mmos4
# SR_aerx12mmos1
# SRp_aerx12mmos1
# SR_aerx12mmos2
# SRp_aerx12mmos2
# SR_aerx12mmos3
# SRp_aerx12mmos3
# SR_aerx12mmos4
# SRp_aerx12mmos4
# SR_aerx15mmos1
# SRp_aerx15mmos1
# SR_aerx15mmos2
# SRp_aerx15mmos2
# SR_aerx15mmos3
# SRp_aerx15mmos3
# SR_aerx15mmos4
# SRp_aerx15mmos4
# SR_aerx18mmos1
# SRp_aerx18mmos1
# SR_aerx18mmos2
# SRp_aerx18mmos2
# SR_aerx18mmos3
# SRp_aerx18mmos3
# SR_aerx18mmos4
# SRp_aerx18mmos4
# SR_aerx24mmos1
# SRp_aerx24mmos1
# SR_aerx24mmos2
# SRp_aerx24mmos2
# SR_aerx24mmos3
# SRp_aerx24mmos3
# SR_aerx24mmos4
# SRp_aerx24mmos4
# SR_aerxbbb24mos
# SRp_aerxbbb24mos
# SR_aerxbbb30mos
# SRp_aerxbbb30mos
# SR_aerxbbb36mos
# SRp_aerxbbb36mos

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from typing import Dict, Any

# =============================================================================
# 0. GLOBAL CONFIGURATION & STATIC DATA (Moved to Global Scope)
# =============================================================================

# Configuration (equivalent to SAS macro variables)
NOTIONAL = 500000.0
PRICE_VOL_SCALING = 252  # Daily to Annual volatility scaling

# Barrier thresholds for the 4 scenarios
CTHRESHOLDS = {1: 0.55, 2: 0.65, 3: 0.75, 4: 0.85}
# Secondary thresholds for calculating 'ibelow' probabilities
MTHRESHOLDS = {1: 0.55, 2: 0.65, 3: 0.75, 4: 0.85}

# Static Data (equivalent to SAS arrays)
TIME_LABELS = {
    1: "3mos", 2: "6mos", 3: "9mos", 4: "12mos", 5: "15mos", 6: "18mos", 7: "24mos",
    8: "6mmos", 9: "9mmos", 10: "12mmos", 11: "15mmos", 12: "18mmos", 13: "24mmos"
}
TIME_PERIODS = {
    1: 0.25, 2: 0.50, 3: 0.75, 4: 1.00, 5: 1.25, 6: 1.50, 7: 2.00,
    8: 0.50, 9: 0.75, 10: 1.00, 11: 1.25, 12: 1.50, 13: 2.00
}
N_OBSERVATIONS = {
    1: 3, 2: 3, 3: 3, 4: 4, 5: 5, 6: 6, 7: 8,
    8: 6, 9: 9, 10: 12, 11: 15, 12: 18, 13: 24
}
# Risk-free rate mapping (SAS: rfrs_barr)
RFR_KEYS = {1: 'DGS3mo', 2: 'DGS6mo', 3: 'dgs9mo', 4: 'DGS1', 5: 'dgs15mo', 6: 'dgs1p5', 7: 'DGS2'}


# =============================================================================
# 1. HELPER FUNCTIONS (Translating SAS Logic)
# =============================================================================

def _calculate_bsm_payouts(
    fin_price: float,
    strike_price: float,
    time_to_maturity: float,
    risk_free_rate: float,
    volatility: float,
    digital_put_payoff: float
) -> float:
    """
    Calculates the structured note's coupon based on embedded options,
    replicating the Black-Scholes-Merton (BSM) logic from the SAS code.
    """
    if volatility <= 0 or fin_price <= 0 or time_to_maturity <= 0:
        return 0.0

    d1 = (np.log(fin_price / strike_price) + (risk_free_rate + volatility**2 / 2) * time_to_maturity) / (volatility * np.sqrt(time_to_maturity))
    d2 = d1 - volatility * np.sqrt(time_to_maturity)

    call_price = (fin_price * norm.cdf(d1) - strike_price * np.exp(-risk_free_rate * time_to_maturity) * norm.cdf(d2))
    put_price = call_price + strike_price * np.exp(-risk_free_rate * time_to_maturity) - fin_price
    digital_put_price = digital_put_payoff * np.exp(-risk_free_rate * time_to_maturity) * norm.cdf(-d2)

    coupon = np.exp(risk_free_rate * time_to_maturity) * (put_price + digital_put_price) / fin_price + (risk_free_rate * time_to_maturity)
    return coupon

def _calculate_aer(
    pr_a: float,
    pr_b: float,
    pr_ib: float,
    coupon: float,
    n_looks: int,
    notional: float,
    fin_price: float,
    mean_bb_price: float,
    num_ncalls: int = 0
) -> float:
    """
    Calculates the expected return based on probabilities of different outcomes.
    This is a direct translation of the core SAS calculation loop for a single scenario.
    """
    if coupon <= 0 or pd.isna(pr_a) or pd.isna(pr_b):
        return 0.0

    shares = notional / fin_price if fin_price > 0 else 0
    payout_constant1 = notional * coupon / n_looks
    payout_constant2 = (mean_bb_price - fin_price) * shares
    payout_constant3 = notional * coupon
    print(pr_a, pr_b)
    pr_g = 1.0 - pr_a - pr_b
    if pr_g < 0: pr_g = 0

    pr_b_last = pr_b - pr_ib

    n_looks_nc0 = n_looks - num_ncalls
    n_looks_nc1 = n_looks - 1 - num_ncalls
    n_looks_nc2 = n_looks - 2 - num_ncalls
    if n_looks_nc2 < 0: return 0.0

    sum_each_pay = 0.0

    if pr_a == 1.0:
        sum_each_pay = payout_constant1 * (num_ncalls + 1)
    elif pr_b == 1.0:
        sum_each_pay = payout_constant2
    else:
        prob = ((pr_b + pr_g) ** n_looks_nc1) * (pr_g + pr_a)
        sum_each_pay += prob * payout_constant3

        if pr_b != pr_b_last and pr_ib > 0:
            for i in range(n_looks_nc2 + 1):
                prob = ((pr_b + pr_g) ** i) * (pr_a + pr_g * (pr_b ** (n_looks_nc2 - i)) * pr_ib)
                payout = payout_constant1 * (i + 1) + payout_constant1 * num_ncalls
                sum_each_pay += prob * payout

            prob = (pr_b ** (n_looks - 1)) * pr_b_last
            sum_each_pay += prob * payout_constant2
            for i in range(1, num_ncalls + 1):
                prob = (pr_g + pr_a) * (pr_b ** (n_looks - 1 - i)) * pr_b_last
                payout = (payout_constant1 * i) + payout_constant2
                sum_each_pay += prob * payout
            for i in range(1, n_looks_nc1 + 1):
                prob = ((pr_b + pr_g) ** (i - 1)) * pr_g * (pr_b ** (n_looks_nc1 - i)) * pr_b_last
                payout = payout_constant1 * (num_ncalls + i) + payout_constant2
                sum_each_pay += prob * payout
            
            for i in range(1, num_ncalls + 1):
                 prob = (pr_g + pr_a) * (pr_b ** (n_looks - 1 - i)) * pr_ib
                 payout = payout_constant1 * i
                 sum_each_pay += prob * payout
        else:
            for i in range(n_looks_nc2 + 1):
                prob = ((pr_b + pr_g) ** i) * pr_a
                payout = payout_constant1 * (i + 1) + payout_constant1 * num_ncalls
                sum_each_pay += prob * payout

            prob = pr_b ** n_looks
            sum_each_pay += prob * payout_constant2
            for i in range(1, num_ncalls + 1):
                prob = (pr_g + pr_a) * (pr_b ** (n_looks - i))
                payout = (payout_constant1 * i) + payout_constant2
                sum_each_pay += prob * payout
            for i in range(1, n_looks_nc1 + 1):
                prob = ((pr_b + pr_g) ** (i - 1)) * pr_g * (pr_b ** (n_looks_nc0 - i))
                payout = payout_constant1 * (num_ncalls + i) + payout_constant2
                sum_each_pay += prob * payout

    return sum_each_pay / notional if notional > 0 else 0.0

# =============================================================================
# 2. MAIN PROCESSING FUNCTION
# =============================================================================

def calculate_all_note_scenarios(data_row: Dict[str, Any]) -> Dict[str, float]:
    """
    Main function to process a single row of data (one ticker at one date)
    and calculate the AER for all defined scenarios.
    """
    results = {}
    fin_price = data_row['adjusted']
    shares = NOTIONAL / fin_price if fin_price > 0 else 0

    for rr in range(1, 5):
        cthreshold = CTHRESHOLDS[rr]
        mthreshold = MTHRESHOLDS[rr]

        for ii in range(1, 14):
            time_label = TIME_LABELS[ii]
            time_period = TIME_PERIODS[ii]
            n_looks = N_OBSERVATIONS[ii]
            vol_and_rfr_key = min(ii, 7)
            
            vol_sas_label = {
                "3mos": "rollstd3mo", "6mos": "rollstd6mo", "9mos": "rollstd9mo",
                "12mos": "rollstd1yr", "15mos": "rollstd15mo", "18mos": "rollstd18mo",
                "24mos": "rollstd24mo"
            }
            # Fallback to 1yr vol if specific one not found
            vol_key = vol_sas_label.get(time_label.replace("mmos", "mos"), 'rollstd1yr')
            
            hist_std = data_row.get(vol_key, data_row['rollstd1yr']) * np.sqrt(PRICE_VOL_SCALING)
            rfr = data_row.get(RFR_KEYS[vol_and_rfr_key], 0) #/ 100.0

            strike_price = fin_price * cthreshold
            digital_payoff = fin_price * (1 - cthreshold)
            coupon = _calculate_bsm_payouts(fin_price, strike_price, time_period, rfr, hist_std, digital_payoff)
            
            tl_correct = time_label.replace("mmos", "mos")
            prob_above = data_row.get(f"pct_above{tl_correct}{rr}", 0)
            prob_below = data_row.get(f"pct_below{tl_correct}{rr}", 0)
            mean_bb_price = data_row.get(f"mean_bb_price{tl_correct}{rr}", 0)
            mean_bb_price = 0 if pd.isna(mean_bb_price) else mean_bb_price
            print(f"mean_bb_price{tl_correct}{rr}")
            # --- Calculate 'pct_ibelow' and 'pr_ib' ---
            # This logic assumes 'pct_ibelow' would be the probability of being below the 'mthreshold'
            # In a full model, this value would be pre-calculated. Here, we simulate it
            # based on the relationship between the two thresholds for a more realistic 'pr_ib'.
            pct_ibelow_simulated = prob_below * (mthreshold / cthreshold)**2 if cthreshold > 0 else 0
            pr_ib = max(prob_below - pct_ibelow_simulated, 0)
            
            # --- Strategic Non-Callable Logic (from SAS) ---
            num_ncalls = 0
            if ii == 2 or ii == 3: num_ncalls = 1 if rr == 1 else 0
            elif ii == 4: num_ncalls = 2 if rr == 1 else (1 if rr == 2 else 0)
            elif ii in [5, 6, 8]: num_ncalls = 2 if rr == 1 else (1 if rr >= 2 else 0)
            elif ii == 7 or ii == 9: num_ncalls = 3 if rr == 1 else (2 if rr >= 2 else 0)
            elif ii == 10: num_ncalls = 4 if rr == 1 else (3 if rr >= 2 else 0)
            elif ii == 11: num_ncalls = 5 if rr == 1 else (4 if rr == 2 else (3 if rr >= 3 else 0))
            elif ii == 12: num_ncalls = 6 if rr == 1 else (5 if rr >= 2 else 0)
            elif ii == 13: num_ncalls = 12 if rr == 1 else (8 if rr == 2 else (6 if rr >= 3 else 0))
            print(time_label)
            aer = _calculate_aer(
                prob_above, prob_below, pr_ib, coupon, n_looks,
                NOTIONAL, fin_price, mean_bb_price, num_ncalls
            )
            
            annualized_aer = aer / time_period if time_period > 0 else 0.0
            results[f"AER_{time_label}_b{rr}"] = annualized_aer
            
    return results

# %%
mean_bb_price3mos1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 mean_bb_price3mos1
#
# NameError: name 'mean_bb_price3mos1' is not defined

# %%
calculate_all_note_scenarios(alltic[0:].to_dict('records')[6975])
# Out:
# mean_bb_price3mos1
# 3mos
# 0.1111111111111111 0.0
# mean_bb_price6mos1
# 6mos
# 0.05555555555555555 0.0
# mean_bb_price9mos1
# 9mos
# 0.037037037037037035 0.0
# mean_bb_price12mos1
# 12mos
# 0.027777777777777776 0.0
# mean_bb_price15mos1
# 15mos
# 0.022222222222222223 0.0
# mean_bb_price18mos1
# 18mos
# 0.019943019943019943 0.0
# mean_bb_price24mos1
# 24mos
# 0.019943019943019943 0.0
# mean_bb_price6mos1
# 6mmos
# 0.05555555555555555 0.0
# mean_bb_price9mos1
# 9mmos
# 0.037037037037037035 0.0
# mean_bb_price12mos1
# 12mmos
# 0.027777777777777776 0.0
# mean_bb_price15mos1
# 15mmos
# 0.022222222222222223 0.0
# mean_bb_price18mos1
# 18mmos
# 0.019943019943019943 0.0
# mean_bb_price24mos1
# 24mmos
# 0.019943019943019943 0.0
# mean_bb_price3mos2
# 3mos
# 0.1111111111111111 0.0
# mean_bb_price6mos2
# 6mos
# 0.05555555555555555 0.0
# mean_bb_price9mos2
# 9mos
# 0.037037037037037035 0.0
# mean_bb_price12mos2
# 12mos
# 0.027777777777777776 0.0
# mean_bb_price15mos2
# 15mos
# 0.022222222222222223 0.0
# mean_bb_price18mos2
# 18mos
# 0.019943019943019943 0.0
# mean_bb_price24mos2
# 24mos
# 0.019943019943019943 0.0
# mean_bb_price6mos2
# 6mmos
# 0.05555555555555555 0.0
# mean_bb_price9mos2
# 9mmos
# 0.037037037037037035 0.0
# mean_bb_price12mos2
# 12mmos
# 0.027777777777777776 0.0
# mean_bb_price15mos2
# 15mmos
# 0.022222222222222223 0.0
# mean_bb_price18mos2
# 18mmos
# 0.019943019943019943 0.0
# mean_bb_price24mos2
# 24mmos
# 0.019943019943019943 0.0
# mean_bb_price3mos3
# 3mos
# 0.1111111111111111 0.0
# mean_bb_price6mos3
# 6mos
# 0.05555555555555555 0.023809523809523808
# mean_bb_price9mos3
# 9mos
# 0.037037037037037035 0.031746031746031744
# mean_bb_price12mos3
# 12mos
# 0.027777777777777776 0.05952380952380952
# mean_bb_price15mos3
# 15mos
# 0.022222222222222223 0.16507936507936508
# mean_bb_price18mos3
# 18mos
# 0.019943019943019943 0.14814814814814814
# mean_bb_price24mos3
# 24mos
# 0.019943019943019943 0.14814814814814814
# mean_bb_price6mos3
# 6mmos
# 0.05555555555555555 0.023809523809523808
# mean_bb_price9mos3
# 9mmos
# 0.037037037037037035 0.031746031746031744
# mean_bb_price12mos3
# 12mmos
# 0.027777777777777776 0.05952380952380952
# mean_bb_price15mos3
# 15mmos
# 0.022222222222222223 0.16507936507936508
# mean_bb_price18mos3
# 18mmos
# 0.019943019943019943 0.14814814814814814
# mean_bb_price24mos3
# 24mmos
# 0.019943019943019943 0.14814814814814814
# mean_bb_price3mos4
# 3mos
# 0.1111111111111111 0.0
# mean_bb_price6mos4
# 6mos
# 0.05555555555555555 0.35714285714285715
# mean_bb_price9mos4
# 9mos
# 0.037037037037037035 0.48148148148148145
# mean_bb_price12mos4
# 12mos
# 0.027777777777777776 0.5833333333333334
# mean_bb_price15mos4
# 15mos
# 0.022222222222222223 0.6190476190476191
# mean_bb_price18mos4
# 18mos
# 0.019943019943019943 0.5612535612535613
# mean_bb_price24mos4
# 24mos
# 0.019943019943019943 0.5612535612535613
# mean_bb_price6mos4
# 6mmos
# 0.05555555555555555 0.35714285714285715
# mean_bb_price9mos4
# 9mmos
# 0.037037037037037035 0.48148148148148145
# mean_bb_price12mos4
# 12mmos
# 0.027777777777777776 0.5833333333333334
# mean_bb_price15mos4
# 15mmos
# 0.022222222222222223 0.6190476190476191
# mean_bb_price18mos4
# 18mmos
# 0.019943019943019943 0.5612535612535613
# mean_bb_price24mos4
# 24mmos
# 0.019943019943019943 0.5612535612535613
# {'AER_3mos_b1': np.float64(0.048764678137442556),
#  'AER_6mos_b1': np.float64(0.0517239831485344),
#  'AER_9mos_b1': np.float64(0.050668656557772994),
#  'AER_12mos_b1': np.float64(0.05117906227695616),
#  'AER_15mos_b1': np.float64(0.06018468135954469),
#  'AER_18mos_b1': np.float64(0.0630823725501202),
#  'AER_24mos_b1': np.float64(0.06746586307430652),
#  'AER_6mmos_b1': np.float64(0.04129409814296424),
#  'AER_9mmos_b1': np.float64(0.04187856225860869),
#  'AER_12mmos_b1': np.float64(0.04414215420552162),
#  'AER_15mmos_b1': np.float64(0.054257168600415004),
#  'AER_18mmos_b1': np.float64(0.058100406824476224),
#  'AER_24mmos_b1': np.float64(0.0656042280941857),
#  'AER_3mos_b2': np.float64(0.04959182976394631),
#  'AER_6mos_b2': np.float64(0.05435202653208162),
#  'AER_9mos_b2': np.float64(0.0568104659623517),
#  'AER_12mos_b2': np.float64(0.06200444482493168),
#  'AER_15mos_b2': np.float64(0.07783638372982186),
#  'AER_18mos_b2': np.float64(0.0799418057906969),
#  'AER_24mos_b2': np.float64(0.0818768058931221),
#  'AER_6mmos_b2': np.float64(0.04449486242937724),
#  'AER_9mmos_b2': np.float64(0.048350270861295036),
#  'AER_12mmos_b2': np.float64(0.05462903117926368),
#  'AER_15mmos_b2': np.float64(0.0713420957523562),
#  'AER_18mmos_b2': np.float64(0.07439199453877228),
#  'AER_24mmos_b2': np.float64(0.07723781980914618),
#  'AER_3mos_b3': np.float64(0.06415561613349313),
#  'AER_6mos_b3': np.float64(0.06485653956668369),
#  'AER_9mos_b3': np.float64(0.06740850587790694),
#  'AER_12mos_b3': np.float64(0.06579534330796835),
#  'AER_15mos_b3': np.float64(0.05909984958505513),
#  'AER_18mos_b3': np.float64(0.06852873504004026),
#  'AER_24mos_b3': np.float64(0.07355250645094237),
#  'AER_6mmos_b3': np.float64(0.056862069937514),
#  'AER_9mmos_b3': np.float64(0.06085585343024141),
#  'AER_12mmos_b3': np.float64(0.06230915432623528),
#  'AER_15mmos_b3': np.float64(0.05915387005103677),
#  'AER_18mmos_b3': np.float64(0.06824187391021634),
#  'AER_24mmos_b3': np.float64(0.07154255388254477),
#  'AER_3mos_b4': np.float64(0.12660847116505936),
#  'AER_6mos_b4': np.float64(-0.027838103949131457),
#  'AER_9mos_b4': np.float64(-0.03993626279948944),
#  'AER_12mos_b4': np.float64(-0.03563151257053543),
#  'AER_15mos_b4': np.float64(-0.01929160964196189),
#  'AER_18mos_b4': np.float64(0.013430858019938359),
#  'AER_24mos_b4': np.float64(0.03274807879006109),
#  'AER_6mmos_b4': np.float64(-0.01244072238145885),
#  'AER_9mmos_b4': np.float64(-0.012052798871998222),
#  'AER_12mmos_b4': np.float64(-0.006397542541716488),
#  'AER_15mmos_b4': np.float64(0.011701951305014065),
#  'AER_18mmos_b4': np.float64(0.034022936318368786),
#  'AER_24mmos_b4': np.float64(0.04808262623439072)}

# %%
alltic.iloc[6975].aer9mos3
# Out:
# np.float64(0.06740850587790694)

# %%
.02713897136329844/2
# Out:
# 0.01356948568164922

# %%
alltic.iloc[0].mean_bb_price12mos4
# Out:
# np.float64(nan)
